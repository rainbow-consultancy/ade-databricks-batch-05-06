# %%
youtube_df = (
    spark.read.format("csv")
    .option("header", True)
    .option("inferSchema", True)
    .load("/Volumes/quant_databricks/batch0506/quantcloudrawdatasets/youtube.csv")
)
youtube_df.display()

# %%
youtube_df.write.format("csv").mode("overwrite").option("header", True).save("/Volumes/quant_databricks/quant-learning/uc-quant-learning/youtube")

# %%
df = spark.read.format("csv").option("header", True).option("inferSchema", True).load("/Volumes/quant_databricks/quant-learning/uc-quant-learning/youtube")
df.display()
